# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link="https://news.ycombinator.com"
page=requests.get(link)
soup=bs(page.content,'html.parser')

# %%
titles=soup.find_all('a',class_='storylink')
title_list=[]
for i in range(0,len(titles)):
    title_list.append(titles[i].get_text())

# %%
score=soup.find_all('span',class_='score')
score_list=[]
for i in range(0,len(score)):
    score_list.append(score[i].get_text())

# %%
url=soup.find_all('span',class_='sitestr')
url_list=[]
for i in range(0,len(url)):
    url_list.append(url[i].get_text())

# %%
import pymongo
from pymongo import MongoClient
try:
    cluster=MongoClient("mongodb+srv://root:1234@cluster0.5f1k2.mongodb.net/localdb?retryWrites=true&w=majority")
    db = cluster["localdb"]
    collection=db["localdb"]
    print("Connected")
except:
    print("Not connected")
# Out:
# Connected

# %%
l=len(url_list)
for i in range(0,l):
    temp={"title":title_list[i]}
    temp1={"URL":url_list[i],"Title":temp}
    collection.insert_one(temp1)

# %%
op=collection.find()
for data in op:
    print(data)
# Out:
# {'_id': ObjectId('5f2fd0828d953f03212373ce'), 'URL': 'preetamnath.com', 'Metadata': {'Title': 'Fire your bad customers', 'Score': '155 points'}}
# {'_id': ObjectId('5f2fd0828d953f03212373cf'), 'URL': 'rarehistoricalphotos.com', 'Metadata': {'Title': 'The German front in rare color photos, 1914-1918', 'Score': '164 points'}}
# {'_id': ObjectId('5f2fd0838d953f03212373d0'), 'URL': 'metadyne.co.uk', 'Metadata': {'Title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)', 'Score': '16 points'}}
# {'_id': ObjectId('5f2fd0838d953f03212373d1'), 'URL': 'twiktwok.github.io', 'Metadata': {'Title': 'Twitter x TikTok = Twiktwok', 'Score': '253 points'}}
# {'_id': ObjectId('5f2fd0848d953f03212373d2'), 'URL': 'wired.com', 'Metadata': {'Title': 'There’s no such thing as a tech expert anymore', 'Score': '47 points'}}
# {'_id': ObjectId('5f2fd0858d953f03212373d3'), 'URL': 'voice.mozilla.org', 'Metadata': {'Title': 'Firefox Voice', 'Score': '183 points'}}
# {'_id': ObjectId('5f2fd0858d953f03212373d4'), 'URL': 'the-other-side.blog', 'Metadata': {'Title': "UPI: India's Unified Payments Interface", 'Score': '257 points'}}
# {'_id': ObjectId('5f2fd0868d953f03212373d5'), 'URL': 'darpa.mil', 'Metadata': {'Title': 'Real Time Machine Learning (2019) [pdf]', 'Score': '114 points'}}
# {'_id': ObjectId('5f2fd0878d953f03212373d6'), 'URL': 'nationalgeographic.com', 'Metadata': {'Title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens', 'Score': '18 points'}}
# {'_id': ObjectId('5f2fd0878d953f03212373d7'), 'URL': 'typing-is-hard.ch', 'Metadata': {'Title': 'Typing Is Hard', 'Score': '168 points'}}
# {'_id': ObjectId('5f2fd0888d953f03212373d8'), 'URL': 'sciencemag.org', 'Metadata': {'Title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets', 'Score': '47 points'}}
# {'_id': ObjectId('5f2fd0888d953f03212373d9'), 'URL': 'romefrontend.dev', 'Metadata': {'Title': 'Rome: A Linter for JavaScript and TypeScript', 'Score': '216 points'}}
# {'_id': ObjectId('5f2fd0898d953f03212373da'), 'URL': 'github.com', 'Metadata': {'Title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)', 'Score': '14 points'}}
# {'_id': ObjectId('5f2fd0898d953f03212373db'), 'URL': 'visionappster.com', 'Metadata': {'Title': 'Overriding C++ virtual functions at run time', 'Score': '7 points'}}
# {'_id': ObjectId('5f2fd08a8d953f03212373dc'), 'URL': 'shankarganesh.blog', 'Metadata': {'Title': 'Business software is so good now, that it’s competing with consumer software', 'Score': '10 points'}}
# {'_id': ObjectId('5f2fd08a8d953f03212373dd'), 'URL': 'devops.com', 'Metadata': {'Title': 'Dear Staging: We’re Done', 'Score': '41 points'}}
# {'_id': ObjectId('5f2fd08b8d953f03212373de'), 'URL': 'fieggen.com', 'Metadata': {'Title': 'C.I.A. Lacing (2014)', 'Score': '176 points'}}
# {'_id': ObjectId('5f2fd08b8d953f03212373df'), 'URL': 'cnbc.com', 'Metadata': {'Title': 'SpaceX and ULA win billions in Pentagon rocket contracts', 'Score': '77 points'}}
# {'_id': ObjectId('5f2fd08c8d953f03212373e0'), 'URL': 'atlasobscura.com', 'Metadata': {'Title': 'The Challenges and Delights of Photographing the Night Sky', 'Score': '21 points'}}
# {'_id': ObjectId('5f2fd08c8d953f03212373e1'), 'URL': 'github.com', 'Metadata': {'Title': 'Hinc: Haskell In New Clothes', 'Score': '3 points'}}
# {'_id': ObjectId('5f2fd08d8d953f03212373e2'), 'URL': 'relinx.io', 'Metadata': {'Title': 'Show HN: Relinx – new kind of Asset tracking – CMDB', 'Score': '6 points'}}
# {'_id': ObjectId('5f2fd08d8d953f03212373e3'), 'URL': 'jatan.space', 'Metadata': {'Title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)', 'Score': '43 points'}}
# {'_id': ObjectId('5f2fd08e8d953f03212373e4'), 'URL': 'iphoneincanada.ca', 'Metadata': {'Title': 'Apple takes legal action against small company with pear logo', 'Score': '621 points'}}
# {'_id': ObjectId('5f2fd08e8d953f03212373e5'), 'URL': 'pnas.org', 'Metadata': {'Title': 'Wheat yield potential in controlled-environment vertical farms', 'Score': '95 points'}}
# {'_id': ObjectId('5f2fd08f8d953f03212373e6'), 'URL': 'newrepublic.com', 'Metadata': {'Title': 'What I Learned from the Worst Novelist in the English Language', 'Score': '40 points'}}
# {'_id': ObjectId('5f2fd08f8d953f03212373e7'), 'URL': 'scientificamerican.com', 'Metadata': {'Title': 'Ask HN: How does your organisation train programmers?', 'Score': '36 points'}}
# {'_id': ObjectId('5f2fd0908d953f03212373e8'), 'URL': 'vector.org.uk', 'Metadata': {'Title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?', 'Score': '14 points'}}
# {'_id': ObjectId('5f2fd0918d953f03212373e9'), 'URL': 'righto.com', 'Metadata': {'Title': 'Water beetles that survive being swallowed by frogs', 'Score': '58 points'}}
# {'_id': ObjectId('5f2fd1108d953f03212373ea'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1108d953f03212373eb'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1118d953f03212373ec'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1118d953f03212373ed'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1128d953f03212373ee'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1128d953f03212373ef'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1138d953f03212373f0'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1138d953f03212373f1'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1138d953f03212373f2'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1148d953f03212373f3'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f4'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f5'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f6'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1168d953f03212373f7'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1168d953f03212373f8'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1178d953f03212373f9'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1188d953f03212373fa'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1188d953f03212373fb'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1198d953f03212373fc'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1198d953f03212373fd'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd11a8d953f03212373fe'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd11a8d953f03212373ff'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd11b8d953f0321237400'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd11b8d953f0321237401'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd11c8d953f0321237402'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd11d8d953f0321237403'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd11d8d953f0321237404'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd11e8d953f0321237405'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd1508d953f0321237406'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1518d953f0321237407'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1518d953f0321237408'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1528d953f0321237409'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1528d953f032123740a'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1528d953f032123740b'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1528d953f032123740c'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1538d953f032123740d'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1538d953f032123740e'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1548d953f032123740f'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1558d953f0321237410'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1558d953f0321237411'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1558d953f0321237412'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1568d953f0321237413'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1568d953f0321237414'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1578d953f0321237415'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1578d953f0321237416'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1588d953f0321237417'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1598d953f0321237418'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1598d953f0321237419'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd1598d953f032123741a'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd15a8d953f032123741b'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd15a8d953f032123741c'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741d'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741e'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741f'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd15c8d953f0321237420'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd15c8d953f0321237421'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd1ce8d953f0321237422'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237423'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237424'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237425'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1d08d953f0321237426'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1d18d953f0321237427'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1d18d953f0321237428'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1d18d953f0321237429'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742a'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742b'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742c'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1d38d953f032123742d'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1d38d953f032123742e'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1d48d953f032123742f'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1d58d953f0321237430'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1d58d953f0321237431'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237432'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237433'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237434'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1d78d953f0321237435'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd1d88d953f0321237436'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd1d98d953f0321237437'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd1d98d953f0321237438'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd1da8d953f0321237439'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd1da8d953f032123743a'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd1db8d953f032123743b'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd1db8d953f032123743c'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd1dc8d953f032123743d'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd2548d953f032123743e'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd2558d953f032123743f'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd2558d953f0321237440'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd2568d953f0321237441'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd2568d953f0321237442'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd2568d953f0321237443'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd2578d953f0321237444'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd2578d953f0321237445'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd2588d953f0321237446'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd2588d953f0321237447'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd2588d953f0321237448'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd2598d953f0321237449'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744a'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744b'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744c'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd25b8d953f032123744d'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd25b8d953f032123744e'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd25c8d953f032123744f'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd25c8d953f0321237450'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd25c8d953f0321237451'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd25d8d953f0321237452'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd25d8d953f0321237453'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd25e8d953f0321237454'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd25f8d953f0321237455'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd2608d953f0321237456'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd2608d953f0321237457'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd2618d953f0321237458'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd2618d953f0321237459'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}

# %%
import pymongo
from pymongo import MongoClient
try:
    cluster=MongoClient("mongodb+srv://root:1234@cluster0.5f1k2.mongodb.net/localdb?retryWrites=true&w=majority")
    db = cluster["localdb"]
    collection=db["localdb1"]
    print("Connected")
except:
    print("Not connected")
# Out:
# Connected

# %%
l=len(url_list)
for i in range(0,l):
    temp={"Title":title_list[i],"Score":score_list[i]}
    temp1={"URL":url_list[i],"Metadata":temp}
    collection.insert_one(temp1)

# %%
result=collection.find()
for data in result:
    print(data)
# Out:
# {'_id': ObjectId('5f2fd0828d953f03212373ce'), 'URL': 'preetamnath.com', 'Metadata': {'Title': 'Fire your bad customers', 'Score': '155 points'}}
# {'_id': ObjectId('5f2fd0828d953f03212373cf'), 'URL': 'rarehistoricalphotos.com', 'Metadata': {'Title': 'The German front in rare color photos, 1914-1918', 'Score': '164 points'}}
# {'_id': ObjectId('5f2fd0838d953f03212373d0'), 'URL': 'metadyne.co.uk', 'Metadata': {'Title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)', 'Score': '16 points'}}
# {'_id': ObjectId('5f2fd0838d953f03212373d1'), 'URL': 'twiktwok.github.io', 'Metadata': {'Title': 'Twitter x TikTok = Twiktwok', 'Score': '253 points'}}
# {'_id': ObjectId('5f2fd0848d953f03212373d2'), 'URL': 'wired.com', 'Metadata': {'Title': 'There’s no such thing as a tech expert anymore', 'Score': '47 points'}}
# {'_id': ObjectId('5f2fd0858d953f03212373d3'), 'URL': 'voice.mozilla.org', 'Metadata': {'Title': 'Firefox Voice', 'Score': '183 points'}}
# {'_id': ObjectId('5f2fd0858d953f03212373d4'), 'URL': 'the-other-side.blog', 'Metadata': {'Title': "UPI: India's Unified Payments Interface", 'Score': '257 points'}}
# {'_id': ObjectId('5f2fd0868d953f03212373d5'), 'URL': 'darpa.mil', 'Metadata': {'Title': 'Real Time Machine Learning (2019) [pdf]', 'Score': '114 points'}}
# {'_id': ObjectId('5f2fd0878d953f03212373d6'), 'URL': 'nationalgeographic.com', 'Metadata': {'Title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens', 'Score': '18 points'}}
# {'_id': ObjectId('5f2fd0878d953f03212373d7'), 'URL': 'typing-is-hard.ch', 'Metadata': {'Title': 'Typing Is Hard', 'Score': '168 points'}}
# {'_id': ObjectId('5f2fd0888d953f03212373d8'), 'URL': 'sciencemag.org', 'Metadata': {'Title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets', 'Score': '47 points'}}
# {'_id': ObjectId('5f2fd0888d953f03212373d9'), 'URL': 'romefrontend.dev', 'Metadata': {'Title': 'Rome: A Linter for JavaScript and TypeScript', 'Score': '216 points'}}
# {'_id': ObjectId('5f2fd0898d953f03212373da'), 'URL': 'github.com', 'Metadata': {'Title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)', 'Score': '14 points'}}
# {'_id': ObjectId('5f2fd0898d953f03212373db'), 'URL': 'visionappster.com', 'Metadata': {'Title': 'Overriding C++ virtual functions at run time', 'Score': '7 points'}}
# {'_id': ObjectId('5f2fd08a8d953f03212373dc'), 'URL': 'shankarganesh.blog', 'Metadata': {'Title': 'Business software is so good now, that it’s competing with consumer software', 'Score': '10 points'}}
# {'_id': ObjectId('5f2fd08a8d953f03212373dd'), 'URL': 'devops.com', 'Metadata': {'Title': 'Dear Staging: We’re Done', 'Score': '41 points'}}
# {'_id': ObjectId('5f2fd08b8d953f03212373de'), 'URL': 'fieggen.com', 'Metadata': {'Title': 'C.I.A. Lacing (2014)', 'Score': '176 points'}}
# {'_id': ObjectId('5f2fd08b8d953f03212373df'), 'URL': 'cnbc.com', 'Metadata': {'Title': 'SpaceX and ULA win billions in Pentagon rocket contracts', 'Score': '77 points'}}
# {'_id': ObjectId('5f2fd08c8d953f03212373e0'), 'URL': 'atlasobscura.com', 'Metadata': {'Title': 'The Challenges and Delights of Photographing the Night Sky', 'Score': '21 points'}}
# {'_id': ObjectId('5f2fd08c8d953f03212373e1'), 'URL': 'github.com', 'Metadata': {'Title': 'Hinc: Haskell In New Clothes', 'Score': '3 points'}}
# {'_id': ObjectId('5f2fd08d8d953f03212373e2'), 'URL': 'relinx.io', 'Metadata': {'Title': 'Show HN: Relinx – new kind of Asset tracking – CMDB', 'Score': '6 points'}}
# {'_id': ObjectId('5f2fd08d8d953f03212373e3'), 'URL': 'jatan.space', 'Metadata': {'Title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)', 'Score': '43 points'}}
# {'_id': ObjectId('5f2fd08e8d953f03212373e4'), 'URL': 'iphoneincanada.ca', 'Metadata': {'Title': 'Apple takes legal action against small company with pear logo', 'Score': '621 points'}}
# {'_id': ObjectId('5f2fd08e8d953f03212373e5'), 'URL': 'pnas.org', 'Metadata': {'Title': 'Wheat yield potential in controlled-environment vertical farms', 'Score': '95 points'}}
# {'_id': ObjectId('5f2fd08f8d953f03212373e6'), 'URL': 'newrepublic.com', 'Metadata': {'Title': 'What I Learned from the Worst Novelist in the English Language', 'Score': '40 points'}}
# {'_id': ObjectId('5f2fd08f8d953f03212373e7'), 'URL': 'scientificamerican.com', 'Metadata': {'Title': 'Ask HN: How does your organisation train programmers?', 'Score': '36 points'}}
# {'_id': ObjectId('5f2fd0908d953f03212373e8'), 'URL': 'vector.org.uk', 'Metadata': {'Title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?', 'Score': '14 points'}}
# {'_id': ObjectId('5f2fd0918d953f03212373e9'), 'URL': 'righto.com', 'Metadata': {'Title': 'Water beetles that survive being swallowed by frogs', 'Score': '58 points'}}
# {'_id': ObjectId('5f2fd1108d953f03212373ea'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1108d953f03212373eb'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1118d953f03212373ec'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1118d953f03212373ed'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1128d953f03212373ee'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1128d953f03212373ef'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1138d953f03212373f0'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1138d953f03212373f1'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1138d953f03212373f2'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1148d953f03212373f3'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f4'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f5'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1158d953f03212373f6'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1168d953f03212373f7'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1168d953f03212373f8'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1178d953f03212373f9'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1188d953f03212373fa'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1188d953f03212373fb'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1198d953f03212373fc'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1198d953f03212373fd'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd11a8d953f03212373fe'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd11a8d953f03212373ff'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd11b8d953f0321237400'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd11b8d953f0321237401'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd11c8d953f0321237402'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd11d8d953f0321237403'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd11d8d953f0321237404'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd11e8d953f0321237405'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd1508d953f0321237406'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1518d953f0321237407'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1518d953f0321237408'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1528d953f0321237409'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1528d953f032123740a'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1528d953f032123740b'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1528d953f032123740c'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1538d953f032123740d'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1538d953f032123740e'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1548d953f032123740f'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1558d953f0321237410'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1558d953f0321237411'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1558d953f0321237412'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1568d953f0321237413'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1568d953f0321237414'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1578d953f0321237415'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1578d953f0321237416'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1588d953f0321237417'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1598d953f0321237418'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1598d953f0321237419'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd1598d953f032123741a'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd15a8d953f032123741b'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd15a8d953f032123741c'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741d'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741e'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd15b8d953f032123741f'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd15c8d953f0321237420'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd15c8d953f0321237421'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd1ce8d953f0321237422'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237423'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237424'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd1cf8d953f0321237425'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd1d08d953f0321237426'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd1d18d953f0321237427'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd1d18d953f0321237428'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd1d18d953f0321237429'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742a'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742b'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd1d28d953f032123742c'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd1d38d953f032123742d'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd1d38d953f032123742e'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd1d48d953f032123742f'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd1d58d953f0321237430'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd1d58d953f0321237431'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237432'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237433'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd1d68d953f0321237434'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd1d78d953f0321237435'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd1d88d953f0321237436'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd1d98d953f0321237437'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd1d98d953f0321237438'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd1da8d953f0321237439'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd1da8d953f032123743a'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd1db8d953f032123743b'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd1db8d953f032123743c'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd1dc8d953f032123743d'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
# {'_id': ObjectId('5f2fd2548d953f032123743e'), 'URL': 'preetamnath.com', 'Title': {'title': 'Fire your bad customers'}}
# {'_id': ObjectId('5f2fd2558d953f032123743f'), 'URL': 'rarehistoricalphotos.com', 'Title': {'title': 'The German front in rare color photos, 1914-1918'}}
# {'_id': ObjectId('5f2fd2558d953f0321237440'), 'URL': 'metadyne.co.uk', 'Title': {'title': 'The ‘-ize’ have it! – About the use of -ise or -ize as an ending (UK practice)'}}
# {'_id': ObjectId('5f2fd2568d953f0321237441'), 'URL': 'twiktwok.github.io', 'Title': {'title': 'Twitter x TikTok = Twiktwok'}}
# {'_id': ObjectId('5f2fd2568d953f0321237442'), 'URL': 'wired.com', 'Title': {'title': 'There’s no such thing as a tech expert anymore'}}
# {'_id': ObjectId('5f2fd2568d953f0321237443'), 'URL': 'voice.mozilla.org', 'Title': {'title': 'Firefox Voice'}}
# {'_id': ObjectId('5f2fd2578d953f0321237444'), 'URL': 'the-other-side.blog', 'Title': {'title': "UPI: India's Unified Payments Interface"}}
# {'_id': ObjectId('5f2fd2578d953f0321237445'), 'URL': 'darpa.mil', 'Title': {'title': 'Real Time Machine Learning (2019) [pdf]'}}
# {'_id': ObjectId('5f2fd2588d953f0321237446'), 'URL': 'nationalgeographic.com', 'Title': {'title': 'Why the U.S. government is allowing bears, wolves to be hunted in their dens'}}
# {'_id': ObjectId('5f2fd2588d953f0321237447'), 'URL': 'typing-is-hard.ch', 'Title': {'title': 'Typing Is Hard'}}
# {'_id': ObjectId('5f2fd2588d953f0321237448'), 'URL': 'sciencemag.org', 'Title': {'title': 'Low-cost measurement of facemask efficacy for filtering expelled droplets'}}
# {'_id': ObjectId('5f2fd2598d953f0321237449'), 'URL': 'romefrontend.dev', 'Title': {'title': 'Rome: A Linter for JavaScript and TypeScript'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744a'), 'URL': 'github.com', 'Title': {'title': 'Show HN: Create diagrams stitching images on a grid using HCL (like Terraform)'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744b'), 'URL': 'visionappster.com', 'Title': {'title': 'Overriding C++ virtual functions at run time'}}
# {'_id': ObjectId('5f2fd25a8d953f032123744c'), 'URL': 'shankarganesh.blog', 'Title': {'title': 'Business software is so good now, that it’s competing with consumer software'}}
# {'_id': ObjectId('5f2fd25b8d953f032123744d'), 'URL': 'devops.com', 'Title': {'title': 'Dear Staging: We’re Done'}}
# {'_id': ObjectId('5f2fd25b8d953f032123744e'), 'URL': 'fieggen.com', 'Title': {'title': 'C.I.A. Lacing (2014)'}}
# {'_id': ObjectId('5f2fd25c8d953f032123744f'), 'URL': 'cnbc.com', 'Title': {'title': 'SpaceX and ULA win billions in Pentagon rocket contracts'}}
# {'_id': ObjectId('5f2fd25c8d953f0321237450'), 'URL': 'atlasobscura.com', 'Title': {'title': 'The Challenges and Delights of Photographing the Night Sky'}}
# {'_id': ObjectId('5f2fd25c8d953f0321237451'), 'URL': 'github.com', 'Title': {'title': 'Hinc: Haskell In New Clothes'}}
# {'_id': ObjectId('5f2fd25d8d953f0321237452'), 'URL': 'relinx.io', 'Title': {'title': 'Show HN: Relinx – new kind of Asset tracking – CMDB'}}
# {'_id': ObjectId('5f2fd25d8d953f0321237453'), 'URL': 'jatan.space', 'Title': {'title': 'Interviewing Mission Director Chandrayaan 1 (that found water on the Moon)'}}
# {'_id': ObjectId('5f2fd25e8d953f0321237454'), 'URL': 'iphoneincanada.ca', 'Title': {'title': 'Apple takes legal action against small company with pear logo'}}
# {'_id': ObjectId('5f2fd25f8d953f0321237455'), 'URL': 'pnas.org', 'Title': {'title': 'Wheat yield potential in controlled-environment vertical farms'}}
# {'_id': ObjectId('5f2fd2608d953f0321237456'), 'URL': 'newrepublic.com', 'Title': {'title': 'What I Learned from the Worst Novelist in the English Language'}}
# {'_id': ObjectId('5f2fd2608d953f0321237457'), 'URL': 'scientificamerican.com', 'Title': {'title': 'Ask HN: How does your organisation train programmers?'}}
# {'_id': ObjectId('5f2fd2618d953f0321237458'), 'URL': 'vector.org.uk', 'Title': {'title': 'Ask HN: Is it a good practice to provide open-source version of your paid app?'}}
# {'_id': ObjectId('5f2fd2618d953f0321237459'), 'URL': 'righto.com', 'Title': {'title': 'Water beetles that survive being swallowed by frogs'}}
